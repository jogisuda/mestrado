# %%
pip install praat-parselmouth
# Out:
# Collecting praat-parselmouth
#   Downloading https://files.pythonhosted.org/packages/09/7b/9fa1172a63b6277603d27bb5613559b5a8888f58e68c1698017b87b0061d/praat_parselmouth-0.3.3-cp36-cp36m-manylinux1_x86_64.whl (9.0MB)
#      |████████████████████████████████| 9.0MB 2.5MB/s
# Requirement already satisfied: numpy>=1.7.0 in /usr/local/lib/python3.6/dist-packages (from praat-parselmouth) (1.18.5)
# Installing collected packages: praat-parselmouth
# Successfully installed praat-parselmouth-0.3.3

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
base_dir = root_dir + "Colab Notebooks/sound"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
os.chdir(base_dir)
for dirname, _, filenames in os.walk(base_dir):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /content/gdrive/My Drive/Colab Notebooks/sound/processed_results.csv
# /content/gdrive/My Drive/Colab Notebooks/sound/8-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/8-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/8-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/7-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/6-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/7-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/7-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/6-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/6-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/5-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/4-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/3-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/4-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/5-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/4-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/5-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/3-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/3-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/2-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/2-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/1-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/10-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/1-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/2-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/1-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/10-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/9-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/9-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/10-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/9-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/70-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/69-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/70-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/70-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/69-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/69-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/67-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/68-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/68-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/68-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/67-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/40-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/39-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/40-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/40-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/39-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/39-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/37-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/38-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/38-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/38-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/37-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/35-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/36-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/36-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/37-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/36-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/35-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/34-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/35-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/34-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/34-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/32-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/32-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/32-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/33-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/33-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/33-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/31-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/31-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/31-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/30-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/29-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/28-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/30-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/30-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/27-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/28-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/28-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/29-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/29-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/27-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/26-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/26-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/27-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/26-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/24-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/24-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/25-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/25-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/25-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/24-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/22-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/22-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/23-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/23-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/23-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/21-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/22-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/21-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/21-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/20-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/20-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/19-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/19-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/19-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/20-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/18-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/18-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/18-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/17-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/17-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/16-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/15-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/15-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/17-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/16-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/14-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/14-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/16-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/15-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/14-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/11-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/12-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/11-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/12-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/12-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/13-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/13-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/13-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/11-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/67-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/66-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/66-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/66-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/65-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/65-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/65-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/64-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/64-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/64-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/63-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/63-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/63-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/62-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/62-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/62-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/61-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/61-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/61-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/59-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/60-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/60-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/60-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/59-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/58-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/59-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/58-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/56-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/57-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/58-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/57-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/56-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/56-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/57-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/55-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/55-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/55-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/53-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/54-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/54-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/53-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/54-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/53-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/52-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/52-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/52-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/50-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/49-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/50-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/50-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/47-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/48-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/49-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/49-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/48-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/48-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/47-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/45-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/45-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/46-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/46-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/46-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/47-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/45-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/44-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/44-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/44-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/41-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/42-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/42-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/42-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/43-a_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/43-u_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/43-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/41-i_n.wav
# /content/gdrive/My Drive/Colab Notebooks/sound/41-a_n.wav

# %%
import glob
import tqdm #te quiero demas, visualiza progresso dos loops
import numpy as np
import pandas as pd
import scipy
import librosa
import matplotlib.pyplot as plt

import parselmouth 
import statistics


from parselmouth.praat import call
from scipy.stats.mstats import zscore
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Agora measurePitch() é uma função que chama vários objetos do praat via parselmouth, e calcula vários tipos do jitter e do shimmer, assim como medidas da F0 e HNR

# %%
def measurePitch(voiceID, f0min, f0max, unit):
    sound = parselmouth.Sound(voiceID) # read the sound
    duration = call(sound, "Get total duration") # duration
    pitch = call(sound, "To Pitch", 0.0, f0min, f0max) #create a praat pitch object
    meanF0 = call(pitch, "Get mean", 0, 0, unit) # get mean pitch
    stdevF0 = call(pitch, "Get standard deviation", 0 ,0, unit) # get standard deviation
    harmonicity = call(sound, "To Harmonicity (cc)", 0.01, f0min, 0.1, 1.0)
    hnr = call(harmonicity, "Get mean", 0, 0)
    pointProcess = call(sound, "To PointProcess (periodic, cc)", f0min, f0max)
    localJitter = call(pointProcess, "Get jitter (local)", 0, 0, 0.0001, 0.02, 1.3)
    localabsoluteJitter = call(pointProcess, "Get jitter (local, absolute)", 0, 0, 0.0001, 0.02, 1.3)
    rapJitter = call(pointProcess, "Get jitter (rap)", 0, 0, 0.0001, 0.02, 1.3)
    ppq5Jitter = call(pointProcess, "Get jitter (ppq5)", 0, 0, 0.0001, 0.02, 1.3)
    ddpJitter = call(pointProcess, "Get jitter (ddp)", 0, 0, 0.0001, 0.02, 1.3)
    localShimmer =  call([sound, pointProcess], "Get shimmer (local)", 0, 0, 0.0001, 0.02, 1.3, 1.6)
    localdbShimmer = call([sound, pointProcess], "Get shimmer (local_dB)", 0, 0, 0.0001, 0.02, 1.3, 1.6)
    apq3Shimmer = call([sound, pointProcess], "Get shimmer (apq3)", 0, 0, 0.0001, 0.02, 1.3, 1.6)
    aqpq5Shimmer = call([sound, pointProcess], "Get shimmer (apq5)", 0, 0, 0.0001, 0.02, 1.3, 1.6)
    apq11Shimmer =  call([sound, pointProcess], "Get shimmer (apq11)", 0, 0, 0.0001, 0.02, 1.3, 1.6)
    ddaShimmer = call([sound, pointProcess], "Get shimmer (dda)", 0, 0, 0.0001, 0.02, 1.3, 1.6)
    
    return duration, meanF0, stdevF0, hnr, localJitter, localabsoluteJitter, rapJitter, ppq5Jitter, ddpJitter, localShimmer, localdbShimmer, apq3Shimmer, aqpq5Shimmer, apq11Shimmer, ddaShimmer

# %% [markdown]
# Aqui plota-se a variância cumulada pelo número de componentes, e printa o número mínimo de comp. que explica mais de 98% da variância cumulada. Ao final retorna-se o valor de PCA com 2 componentes apenas (só por simplicidade)

# %%
def runPCA(df):
    # z-score the Jitter and Shimmer measurements
    measures = ['localJitter', 'localabsoluteJitter', 'rapJitter', 'ppq5Jitter', 'ddpJitter',
                'localShimmer', 'localdbShimmer', 'apq3Shimmer', 'apq5Shimmer', 'apq11Shimmer', 'ddaShimmer']
    x = df.loc[:, measures].values #pega as colunas da lista 'measures' na planilha
    x = StandardScaler().fit_transform(x) #normalização
    # PCA
    pca = PCA().fit(x)
    varCumulada = np.cumsum(pca.explained_variance_ratio_) #variância cumulada pelo número de componentes
    plt.plot(varCumulada)
    plt.xlabel('number of components')
    plt.ylabel('cumulative explained variance')
    plt.show()

    n_components = np.argmax(varCumulada > 0.98) + 1 #pegamos qual índice do nosso vetor corresponde a mais de 98% da var., soma 1 pq começa em 0
    print("Componentes: ", n_components, "Var: ", varCumulada[n_components - 1])
    principalComponents = PCA(n_components=2).fit_transform(x) #mudar 2 para n_components se for pegar os comp. > 98%
    principalDf = pd.DataFrame(data = principalComponents, columns = ['JitterPCA', 'ShimmerPCA'])
    return principalDf

# %%
# cria listas das features
file_list = []
duration_list = []
mean_F0_list = []
sd_F0_list = []
hnr_list = []
localJitter_list = []
localabsoluteJitter_list = []
rapJitter_list = []
ppq5Jitter_list = []
ddpJitter_list = []
localShimmer_list = []
localdbShimmer_list = []
apq3Shimmer_list = []
aqpq5Shimmer_list = []
apq11Shimmer_list = []
ddaShimmer_list = []

# %% [markdown]
# Agora o for abaixo itera todos os .wav no diretório, e pra cada arquivo de áudio, armazena as features dele nas listas criadas acima.

# %%
# Go through all the wave files in the folder and measure all the acoustics
for wave_file in glob.glob(base_dir + "/*.wav"):
    sound = parselmouth.Sound(wave_file)
    (duration, meanF0, stdevF0, hnr, localJitter, localabsoluteJitter, rapJitter, ppq5Jitter, ddpJitter, 
     localShimmer, localdbShimmer, apq3Shimmer, aqpq5Shimmer, apq11Shimmer, ddaShimmer) = measurePitch(
        sound, 75, 300, "Hertz")
    file_list.append(wave_file) # make an ID list
    duration_list.append(duration) # make duration list
    mean_F0_list.append(meanF0) # make a mean F0 list
    sd_F0_list.append(stdevF0) # make a sd F0 list
    hnr_list.append(hnr) #add HNR data
    
    # add raw jitter and shimmer measures
    localJitter_list.append(localJitter)
    localabsoluteJitter_list.append(localabsoluteJitter)
    rapJitter_list.append(rapJitter)
    ppq5Jitter_list.append(ppq5Jitter)
    ddpJitter_list.append(ddpJitter)
    localShimmer_list.append(localShimmer)
    localdbShimmer_list.append(localdbShimmer)
    apq3Shimmer_list.append(apq3Shimmer)
    aqpq5Shimmer_list.append(aqpq5Shimmer)
    apq11Shimmer_list.append(apq11Shimmer)
    ddaShimmer_list.append(ddaShimmer)

# %% [markdown]
# Aqui com as features já em mãos, executa então o PCA e salva os resultados numa planilha.

# %%
# Add the data to Pandas
df = pd.DataFrame(np.column_stack([file_list, duration_list, mean_F0_list, sd_F0_list, hnr_list, 
                                   localJitter_list, localabsoluteJitter_list, rapJitter_list, 
                                   ppq5Jitter_list, ddpJitter_list, localShimmer_list, 
                                   localdbShimmer_list, apq3Shimmer_list, aqpq5Shimmer_list, 
                                   apq11Shimmer_list, ddaShimmer_list]),
                                   columns=['voiceID', 'duration', 'meanF0Hz', 'stdevF0Hz', 'HNR', 
                                            'localJitter', 'localabsoluteJitter', 'rapJitter', 
                                            'ppq5Jitter', 'ddpJitter', 'localShimmer', 
                                            'localdbShimmer', 'apq3Shimmer', 'apq5Shimmer', 
                                            'apq11Shimmer', 'ddaShimmer'])

pcaData = runPCA(df) # Run jitter and shimmer PCA
df = pd.concat([df, pcaData], axis=1) # Add PCA data
# reload the data so it's all numbers
df.to_csv("processed_results.csv", index=False)
df = pd.read_csv('processed_results.csv', header=0)
df.sort_values('voiceID').head(15)
# Out:
# Componentes:  4 Var:  0.9942639743500218
#                                               voiceID  ...  ShimmerPCA
# 0   /content/gdrive/My Drive/Colab Notebooks/sound...  ...   -1.141348
# 2   /content/gdrive/My Drive/Colab Notebooks/sound...  ...    0.262562
# 1   /content/gdrive/My Drive/Colab Notebooks/sound...  ...   -0.463758
# 39  /content/gdrive/My Drive/Colab Notebooks/sound...  ...   -0.545232
# 9   /content/gdrive/My Drive/Colab Notebooks/sound...  ...   -2.508162
# 20  /content/gdrive/My Drive/Colab Notebooks/sound...  ...   -4.646315
# 29  /content/gdrive/My Drive/Colab Notebooks/sound...  ...    1.502652
# 3   /content/gdrive/My Drive/Colab Notebooks/sound...  ...    0.187371
# 30  /content/gdrive/My Drive/Colab Notebooks/sound...  ...   -0.078771
# 8   /content/gdrive/My Drive/Colab Notebooks/sound...  ...   -0.397366
# 23  /content/gdrive/My Drive/Colab Notebooks/sound...  ...    0.561418
# 11  /content/gdrive/My Drive/Colab Notebooks/sound...  ...   -0.667167
# 52  /content/gdrive/My Drive/Colab Notebooks/sound...  ...   -0.610500
# 67  /content/gdrive/My Drive/Colab Notebooks/sound...  ...   -0.348764
# 65  /content/gdrive/My Drive/Colab Notebooks/sound...  ...    0.662282
#
# [15 rows x 18 columns]
